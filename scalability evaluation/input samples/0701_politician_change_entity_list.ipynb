# %%
import pandas as pd

doc = pd.read_excel("0701manual_15000politician_change_statements.xlsx")

entity_list = (
    doc[["QID"]]
    .dropna()
    .drop_duplicates()
    .reset_index(drop=True)
)

entity_list.to_excel(
    "0701manual_15000politician_change_entities.xlsx",
    index=False
)

print(f"Number of entities: {len(entity_list)}")
print("Saved to 0701manual_15000politician_change_entities.xlsx")
# Out:
# Number of entities: 13661
# Saved to 0701manual_15000politician_change_entities.xlsx
